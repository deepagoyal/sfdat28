# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
##### INDEED #####

# a job posting website (as well as resume hosting)
# scrape some (or A LOT) of job postings from indeed for the job "data scientist"
# Plan of Action:
# http://www.indeed.com/jobs?q=data+scientist&l=San+Francisco%2C+CA
# 1. Figure out the url for getting the summaries (by doing it yourself!)
# 2. Scrape the summary
# 3. Figure out how to change the page by changing the URL (hint, click the next page button and see how the url changes)
# 4. BONUS: count the most used words in the sumaries
r = requests.get('http://www.indeed.com/jobs?q=data+scientist&l=San+Francisco%2C+CA')
b = BeautifulSoup(r.text, 'html.parser')
b.prettify()
# Out:
# u'<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="text/html;charset=utf-8" http-equiv="content-type">\n   <!-- pll -->\n   <script src="/s/2c2181b/en_US.js" type="text/javascript">\n   </script>\n   <link href="/s/6aa5893/jobsearch_all.css" rel="stylesheet" type="text/css">\n    <link href="http://rss.indeed.com/rss?q=data+scientist&amp;l=San+Francisco%2C+CA" rel="alternate" title="Data Scientist Jobs, Employment in San Francisco, CA" type="application/rss+xml">\n     <link href="/m/jobs?q=data+scientist&amp;l=San+Francisco%2C+CA" media="handheld" rel="alternate">\n      <script type="text/javascript">\n       window[\'closureReadyCallbacks\'] = [];\n\n    function call_when_jsall_loaded(cb) {\n        if (window[\'closureReady\']) {\n            cb();\n        } else {\n            window[\'closureReadyCallbacks\'].push(cb);\n        }\n    }\n      </script>\n      <script src="/s/9c4e3d7/jobsearch-all-compiled.js" type="text/javascript">\n      </script>\n      <script type="text/javascript">\n       var pingUrlsForGA = [];\n\nvar searchUID = \'1avj18de1b9pkbob\';\nvar tk = \'1avj18de1b9pkbob\';\n\nvar loggedIn = false;\nvar myindeed = true;\nvar userEmail = \'\';\nvar tellFriendEmail = \'\';\nvar globalLoginURL = \'http:\\/\\/www.indeed.com\\/account\\/login?dest=%2Fq-data-scientist-l-San-Francisco%2C-CA-jobs.html\';\nvar globalRegisterURL = \'http:\\/\\/www.indeed.com\\/account\\/register?dest=%2Fq-data-scientist-l-San-Francisco%2C-CA-jobs.html\';\nvar searchKey = \'eb375d2d819827bb\';\nvar searchState = \'q=data+scientist&amp;l=San+Francisco%2C+CA\';\nvar searchQS = \'q=data+scientist&l=San+Francisco,+CA\';\nvar eventType = \'jobsearch\';\nvar locale = \'en_US\';\nfunction clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf(\'&jsa=\'); if (si > 0) return; var jsh = hr + \'&tk=1avj18de1b9pkbob&jsa=6689\'; a.href = jsh; }\nfunction sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf(\'&oc=1\'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }\nfunction sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + \'&oc=1&sal=\'+sal; }\nfunction ptk(st,p) {document.cookie = \'PTK="tk=1avj18de1b9pkbob&type=jobsearch&subtype=\'+st+(p?\'&\'+p:\'\')+\'"; path=/\';}\nfunction rbptk(st, c, p) { ptk(st, \'cat=\'+c+(p?\'&p=\'+p:\'\'));}\n      </script>\n      <script type="text/javascript">\n       function loadJSAsync( ) {\nfor ( var i = 0; i < arguments.length; i++ ) {\nvar url = arguments[i];\n(function() {\nvar s = document.createElement("script"), el = document.getElementsByTagName("script")[0];\ns.async = true;\ns.src = url;\nel.parentNode.insertBefore(s, el);\n})();\n}\n}\n      </script>\n      <meta content="1,922  Data Scientist Jobs available in San Francisco, CA on Indeed.com.  one search.  all jobs." name="description">\n       <meta content="Data Scientist Jobs, Employment in San Francisco, CA, San Francisco, CA careers, San Francisco, CA employment, San Francisco, CA job listings, San Francisco, CA job search, San Francisco, CA search engine, work in San Francisco, CA" name="keywords">\n        <link href="/q-Data-Scientist-l-San-Francisco,-CA-jobs.html" rel="canonical">\n         <link href="/jobs?q=data+scientist&amp;l=San+Francisco%2C+CA&amp;start=10" rel="next"/>\n         <style type="text/css">\n          #recPromoDisplay { margin-bottom: 3em;margin-left: 0.5em; }\n#recPromoDisplayPageLast { font-size: 16px; margin: 1.5em 0; }\n         </style>\n         <script type="text/javascript">\n          var indeedCsrfToken = \'itIHsIEwLRjPYIFMC6nv0XH6BEQz6NxO\';\nvar hashedCsrfToken = \'a4d9a9c8a1271feeb735fc6efb85b74f\';\n         </script>\n         <style type="text/css">\n          .jasxcustomfonttst-useCustomHostedFontFullPage *{font-family:"Open Sans", sans-serif !important}.jasxcustomfonttst-useLato *{font-family:"Lato", sans-serif !important}.jasxcustomfonttst-useFira *{fon ...

# %%
b.findAll('span')
# Out:
# [<span id="accessibilityText">Skip to <!-- This is translated before reaching this state --><a class="accessibilityMenu" href="#jobPostingsAnchor" id="skipToJobs">Job Postings</a>, <!-- This is translated before reaching this state --><a class="accessibilityMenu" href="#what" id="skipToSearch">Search</a></span>,
#  <span class="navBi"><a class="selected" href="/" id="jobsLink" title="Jobs">Find Jobs</a></span>,
#  <span class="navBi"><a href="/resumes?isid=find-resumes&amp;ikw=SERPtop&amp;co=US&amp;hl=en" id="rezLink">Find Resumes</a></span>,
#  <span class="navBi"><a href="/hire?hl=en&amp;cc=US" id="empLink" onclick="if ( this.href.match('&amp;isid=employerlink-US-control&amp;ikw=SERPtop') == null ) { this.href += '&amp;isid=employerlink-US-control&amp;ikw=SERPtop' };">Employers / Post Job</a></span>,
#  <span class="navBi"><span class="resume-promo" id="navpromo">\n<a href="/promo/resume" onclick="window.location=this.href + '?from=nav&amp;subfrom=rezprmstd&amp;trk.origin=jobsearch&amp;trk.variant=rezprmstd&amp;trk.tk=1avj18de1b9pkbob'; return false;">Upload your resume</a>\n</span></span>,
#  <span class="resume-promo" id="navpromo">\n<a href="/promo/resume" onclick="window.location=this.href + '?from=nav&amp;subfrom=rezprmstd&amp;trk.origin=jobsearch&amp;trk.variant=rezprmstd&amp;trk.tk=1avj18de1b9pkbob'; return false;">Upload your resume</a>\n</span>,
#  <span class="navBi"><a href="http://www.indeed.com/account/login?dest=%2Fjobs%3Fq%3Ddata%2Bscientist%26l%3DSan%2BFrancisco%2C%2BCA" id="userOptionsLabel" rel="nofollow">Sign in</a></span>,
#  <span id="hidden_colon" style="display:none">:</span>,
#  <span class="inwrap"><input aria-labelledby="what_label_top hidden_colon what_label" class="input_text" id="what" maxlength="512" name="q" size="31" value="data scientist"/></span>,
#  <span class="inwrap"><input aria-labelledby="where_label_top hidden_colon where_label" class="input_text" id="where" maxlength="45" name="l" size="27" value="San Francisco, CA"/></span>,
#  <span class="inwrapBorder" style="width:auto;padding-right:0;"><span class="inwrapBorderTop"><input class="input_submit" id="fj" type="submit" value="Find Jobs"/></span></span>,
#  <span class="inwrapBorderTop"><input class="input_submit" id="fj" type="submit" value="Find Jobs"/></span>,
#  <span class="h">\xa0</span>,
#  <span class="h">\xa0</span>,
#  <span class="h">\xa0</span>,
#  <span aria-level="2" role="heading" style="height: 0; overflow: hidden; position: absolute;">Filter results by:</span>,
#  <span aria-level="3" class="ws_bold" role="heading">\nSalary Estimate</span>,
#  <span aria-level="3" class="ws_bold" role="heading">\nJob Type</span>,
#  <span aria-level="3" class="ws_bold" role="heading">\nLocation</span>,
#  <span onclick="showAllRefinements('rb_Location'); return false;" onkeyup="if (event.keyCode == 13) showAllRefinements('rb_Location'); return false;" tabindex="0">more \xbb</span>,
#  <span aria-level="3" class="ws_bold" role="heading">\nCompany</span>,
#  <span onclick="showAllRefinements('rb_Company'); return false;" onkeyup="if (event.keyCode == 13) showAllRefinements('rb_Company'); return false;" tabindex="0">more \xbb</span>,
#  <span aria-level="3" class="ws_bold" role="heading">\nExperience Level</span>,
#  <span class="new">New!</span>,
#  <span class="company">\n    Blue Owl</span>,
#  <span class="location">San Francisco, CA</span>,
#  <span class="summary">Requirements for all <b>data</b> <b>scientists</b>. Expert in Python and core libraries used by <b>data</b> <b>scientists</b> (Numpy, Scipy, Pandas, Scikit-learn, Matplotlib/Seaborn, etc.)...</span>,
#  <span class="date">30+ days ago</span>,
#  <span class="tt_set" id="tt_set_10"></span>,
#  <span class="sdn">Sponsored</span>,
#  <span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Workday" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=f1e669a5d6e98326&amp;jcid=9ac45d217f8342a1')" target="_blank">\n        Workday</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 42.0px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 42.0px;"><!-- --></span>,
#  <span class="slNoUnderline">13 reviews</span>,
#  <span class="location">Pleasanton, CA 94588</span>,
#  <span class="summary">In addition to projects, you will be able to learn from fellow top notch <b>data</b> <b>scientists</b> and engineers, follow and share cutting-edge machine learning and deep...</span>,
#  <span class="date">30+ days ago</span>,
#  <span class="tt_set" id="tt_set_11"></span>,
#  <span class="sdn">Sponsored</span>,
#  <span class="company">\n    HP Inc</span>,
#  <span class="location">Palo Alto, CA</span>,
#  <span class="summary">The Customer and Marketing Analytics group in HP Inc\u2019s Global Marketing organization has been charted to provide deep insights, predictions and optimization...</span>,
#  <span class="date">3 days ago</span>,
#  <span class="tt_set" id="tt_set_12"></span>,
#  <span class="sdn">Sponsored by <b>HP</b></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Twitch" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=85e94cc9adaabf4d&amp;jcid=4e78d35dbff06279')" target="_blank">\n        Twitch</a></span>\n</span>,
#  <span itemprop="name">\n<a href="/cmp/Twitch" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=85e94cc9adaabf4d&amp;jcid=4e78d35dbff06279')" target="_blank">\n        Twitch</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 55.800003px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 55.800003px;"><!-- --></span>,
#  <span class="slNoUnderline">4 reviews</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span>,
#  <span itemprop="addressLocality">San Francisco, CA</span>,
#  <span class="summary" itemprop="description">\nWe think of Emmett, the CEO, as Twitch\u2019s original <b>data</b> <b>scientist</b>. Professional work as a <b>Data</b> <b>Scientist</b> at a web/mobile product company is preferred, but any...</span>,
#  <span class="date">8 days ago</span>,
#  <span class="tt_set" id="tt_set_0"> - <span class="savelink2" id="savelink2_85e94cc9adaabf4d"><a class="sl resultLink save-job-link" href="#" id="sj_85e94cc9adaabf4d" onclick="changeJobState('85e94cc9adaabf4d', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_0" onclick="toggleMoreLinks('85e94cc9adaabf4d'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_85e94cc9adaabf4d"><a class="sl resultLink save-job-link" href="#" id="sj_85e94cc9adaabf4d" onclick="changeJobState('85e94cc9adaabf4d', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/q-Twitch-l-San-Francisco,-CA-jobs.html" rel="nofollow">Twitch jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in San Francisco, CA</a></span>,
#  <span class="mat">Learn more about working at <a href="/cmp/Twitch" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=85e94cc9adaabf4d&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=4e78d35dbff06279');">Twitch</a></span>,
#  <span class="mat">Related forums: <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a> - <a href="/forum/cmp/Twitch.html">Twitch</a></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Production Modeling Corporation</span>\n</span>,
#  <span itemprop="name">\n    Production Modeling Corporation</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span>,
#  <span itemprop="addressLocality">San Francisco, CA</span>,
#  <span class="summary" itemprop="description">\nWe are looking for a sharp, disciplined, and highly quantitative individual who has a passion for <b>data</b> mining and <b>data</b> analytics....</span>,
#  <span class="iaLabel"> Easily apply</span>,
#  <span class="date">2 days ago</span>,
#  <span class="tt_set" id="tt_set_1"> - <span class="savelink2" id="savelink2_a6055a62968fc219"><a class="sl resultLink save-job-link" href="#" id="sj_a6055a62968fc219" onclick="changeJobState('a6055a62968fc219', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('a6055a62968fc219'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_a6055a62968fc219"><a class="sl resultLink save-job-link" href="#" id="sj_a6055a62968fc219" onclick="changeJobState('a6055a62968fc219', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/jobs?q=Production+Modeling+Corporation&amp;l=San+Francisco,+CA&amp;nc=jasx" rel="nofollow">Production Modeling Corporation jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in San Francisco, CA</a></span>,
#  <span class="mat">Learn more about working at <a href="/cmp/Production-Modeling-Corporation-1" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=a6055a62968fc219&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=06a24f7521934721');">Production Modeling Corporation</a></span>,
#  <span class="mat">Related forums: <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a> - <a href="/forum/cmp/Production-Modeling-Corporation-1.html">Production Modeling Corporation</a></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Hoodline</span>\n</span>,
#  <span itemprop="name">\n    Hoodline</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span>,
#  <span itemprop="addressLocality">San Francisco, CA</span>,
#  <span class="summary" itemprop="description">\nDevelop machine learning and <b>data</b> mining algorithms to extract meaningful information from thousand to millions articles....</span>,
#  <span class="iaLabel"> Easily apply</span>,
#  <span class="date">8 days ago</span>,
#  <span class="tt_set" id="tt_set_2"> - <span class="savelink2" id="savelink2_dd86068e34d0f55a"><a class="sl resultLink save-job-link" href="#" id="sj_dd86068e34d0f55a" onclick="changeJobState('dd86068e34d0f55a', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('dd86068e34d0f55a'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_dd86068e34d0f55a"><a class="sl resultLink save-job-link" href="#" id="sj_dd86068e34d0f55a" onclick="changeJobState('dd86068e34d0f55a', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/q-Hoodline-l-San-Francisco,-CA-jobs.html" rel="nofollow">Hoodline jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Machine+Learning+Data+Scientist&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Machine Learning Data Scientist salaries in San Francisco, CA</a></span>,
#  <span class="mat">Learn more about working at <a href="/cmp/Hoodline" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=dd86068e34d0f55a&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=4fd93d765aa9a423');">Hoodline</a></span>,
#  <span class="mat">Related forums: <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a> - <a href="/forum/cmp/Hoodline.html">Hoodline</a></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Macy's" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=0af2239cd618e17c&amp;jcid=6df24d87c9f05a07')" target="_blank">\n        Macy's</a></span>\n</span>,
#  <span itemprop="name">\n<a href="/cmp/Macy's" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=0af2239cd618e17c&amp;jcid=6df24d87c9f05a07')" target="_blank">\n        Macy's</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.2px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.2px;"><!-- --></span>,
#  <span class="slNoUnderline">14,211 reviews</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span>,
#  <span itemprop="addressLocality">San Francisco, CA</span>,
#  <span class="summary" itemprop="description">\nThe <b>Data</b> <b>Scientist</b> function enables and empowers macys.com marketing and site personalization with predictive modeling, forecasting, <b>data</b> mining, experimental...</span>,
#  <span class="date">7 days ago</span>,
#  <span class="tt_set" id="tt_set_3"> - <span class="savelink2" id="savelink2_0af2239cd618e17c"><a class="sl resultLink save-job-link" href="#" id="sj_0af2239cd618e17c" onclick="changeJobState('0af2239cd618e17c', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_3" onclick="toggleMoreLinks('0af2239cd618e17c'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_0af2239cd618e17c"><a class="sl resultLink save-job-link" href="#" id="sj_0af2239cd618e17c" onclick="changeJobState('0af2239cd618e17c', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/jobs?q=Macy%27s&amp;l=San+Francisco,+CA" rel="nofollow">Macy's jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in San Francisco, CA</a></span>,
#  <span class="mat">Learn more about working at <a href="/cmp/Macy's" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=0af2239cd618e17c&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=6df24d87c9f05a07');">Macy's</a></span>,
#  <span class="mat">Related forums: <a href="/forum/cmp/Macy%27s.html">Macy's</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Ubisoft" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=30768ffa71fdfbc4&amp;jcid=237908de095b6446')" target="_blank">\n        Ubisoft</a></span>\n</span>,
#  <span itemprop="name">\n<a href="/cmp/Ubisoft" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=30768ffa71fdfbc4&amp;jcid=237908de095b6446')" target="_blank">\n        Ubisoft</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 51.0px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 51.0px;"><!-- --></span>,
#  <span class="slNoUnderline">68 reviews</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA 94107 <span style="font-size: smaller">(South Of Market area)</span></span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA 94107 <span style="font-size: smaller">(South Of Market area)</span></span></span>,
#  <span itemprop="addressLocality">San Francisco, CA 94107 <span style="font-size: smaller">(South Of Market area)</span></span>,
#  <span style="font-size: smaller">(South Of Market area)</span>,
#  <span class="summary" itemprop="description">\nThe most commons will be SQL for <b>data</b> extraction, R for <b>data</b> analysis and a. Combination of R and Tableau for <b>data</b> visualization ....</span>,
#  <span class="date">8 days ago</span>,
#  <span class="tt_set" id="tt_set_4"> - <span class="savelink2" id="savelink2_30768ffa71fdfbc4"><a class="sl resultLink save-job-link" href="#" id="sj_30768ffa71fdfbc4" onclick="changeJobState('30768ffa71fdfbc4', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_4" onclick="toggleMoreLinks('30768ffa71fdfbc4'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_30768ffa71fdfbc4"><a class="sl resultLink save-job-link" href="#" id="sj_30768ffa71fdfbc4" onclick="changeJobState('30768ffa71fdfbc4', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/q-Ubisoft-l-San-Francisco,-CA-jobs.html" rel="nofollow">Ubisoft jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in San Francisco, CA</a></span>,
#  <span class="mat">Learn more about working at <a href="/cmp/Ubisoft" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=30768ffa71fdfbc4&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=237908de095b6446');">Ubisoft</a></span>,
#  <span class="mat">Related forums: <a href="/forum/cmp/Ubisoft.html">Ubisoft</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Yelp" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=0831dc37aed855a5&amp;jcid=0e94073a1c937bd1')" target="_blank">\n        Yelp</a></span>\n</span>,
#  <span itemprop="name">\n<a href="/cmp/Yelp" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=0831dc37aed855a5&amp;jcid=0e94073a1c937bd1')" target="_blank">\n        Yelp</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;"><!-- --></span>,
#  <span class="slNoUnderline">121 reviews</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA 94103 <span style="font-size: smaller">(South Of Market area)</span></span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA 94103 <span style="font-size: smaller">(South Of Market area)</span></span></span>,
#  <span itemprop="addressLocality">San Francisco, CA 94103 <span style="font-size: smaller">(South Of Market area)</span></span>,
#  <span style="font-size: smaller">(South Of Market area)</span>,
#  <span class="summary" itemprop="description">\nEndless ideas about how to leverage Yelp's unique <b>data</b> set. Interested in applying? In this role you\u2019ll be tackling a variety of projects ranging from design...</span>,
#  <span class="date">20 days ago</span>,
#  <span class="tt_set" id="tt_set_5"> - <span class="savelink2" id="savelink2_0831dc37aed855a5"><a class="sl resultLink save-job-link" href="#" id="sj_0831dc37aed855a5" onclick="changeJobState('0831dc37aed855a5', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_5" onclick="toggleMoreLinks('0831dc37aed855a5'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_0831dc37aed855a5"><a class="sl resultLink save-job-link" href="#" id="sj_0831dc37aed855a5" onclick="changeJobState('0831dc37aed855a5', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/q-Yelp-l-San-Francisco,-CA-jobs.html" rel="nofollow">Yelp jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in San Francisco, CA</a></span>,
#  <span class="mat">Learn more about working at <a href="/cmp/Yelp" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=0831dc37aed855a5&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=0e94073a1c937bd1');">Yelp</a></span>,
#  <span class="mat">Related forums: <a href="/forum/cmp/Yelp.html">Yelp</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Uber" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=75aa39e38a1a0621&amp;jcid=f766f8bfbc3effb7')" target="_blank">\n        Uber</a></span>\n</span>,
#  <span itemprop="name">\n<a href="/cmp/Uber" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=75aa39e38a1a0621&amp;jcid=f766f8bfbc3effb7')" target="_blank">\n        Uber</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span>,
#  <span class="slNoUnderline">73 reviews</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA 94105 <span style="font-size: smaller">(Financial District area)</span></span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA 94105 <span style="font-size: smaller">(Financial District area)</span></span></span>,
#  <span itemprop="addressLocality">San Francisco, CA 94105 <span style="font-size: smaller">(Financial District area)</span></span>,
#  <span style="font-size: smaller">(Financial District area)</span>,
#  <span class="summary" itemprop="description">\nYour work will be leveraged by users across Uber so you\u2019ll need to work effectively with a cross-functional team of <b>data</b> <b>scientists</b> and engineers to ensure...</span>,
#  <span class="date">1 day ago</span>,
#  <span class="tt_set" id="tt_set_6"> - <span class="savelink2" id="savelink2_75aa39e38a1a0621"><a class="sl resultLink save-job-link" href="#" id="sj_75aa39e38a1a0621" onclick="changeJobState('75aa39e38a1a0621', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('75aa39e38a1a0621'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_75aa39e38a1a0621"><a class="sl resultLink save-job-link" href="#" id="sj_75aa39e38a1a0621" onclick="changeJobState('75aa39e38a1a0621', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/q-Uber-l-San-Francisco,-CA-jobs.html" rel="nofollow">Uber jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Data+Science&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Science salaries in San Francisco, CA</a></span>,
#  <span class="mat">Learn more about working at <a href="/cmp/Uber" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=75aa39e38a1a0621&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=f766f8bfbc3effb7');">Uber</a></span>,
#  <span class="mat">Related forums: <a href="/forum/cmp/Uber.html">Uber</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Apple" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=b1c75056addc71fd&amp;jcid=c1099851e9794854')" target="_blank">\n        Apple</a></span>\n</span>,
#  <span itemprop="name">\n<a href="/cmp/Apple" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=b1c75056addc71fd&amp;jcid=c1099851e9794854')" target="_blank">\n        Apple</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 52.800003px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 52.800003px;"><!-- --></span>,
#  <span class="slNoUnderline">2,581 reviews</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA 94114 <span style="font-size: smaller">(Castro-Upper Market area)</span></span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA 94114 <span style="font-size: smaller">(Castro-Upper Market area)</span></span></span>,
#  <span itemprop="addressLocality">San Francisco, CA 94114 <span style="font-size: smaller">(Castro-Upper Market area)</span></span>,
#  <span style="font-size: smaller">(Castro-Upper Market area)</span>,
#  <span class="summary" itemprop="description">\nWe are looking for <b>scientists</b> who are passionate about creating <b>data</b> driven systems and have experience in statistical programming, machine learning, and use of...</span>,
#  <span class="date">8 days ago</span>,
#  <span class="tt_set" id="tt_set_7"> - <span class="savelink2" id="savelink2_b1c75056addc71fd"><a class="sl resultLink save-job-link" href="#" id="sj_b1c75056addc71fd" onclick="changeJobState('b1c75056addc71fd', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('b1c75056addc71fd'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_b1c75056addc71fd"><a class="sl resultLink save-job-link" href="#" id="sj_b1c75056addc71fd" onclick="changeJobState('b1c75056addc71fd', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/q-Apple-l-San-Francisco,-CA-jobs.html" rel="nofollow">Apple jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Software+Engineer&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Software Engineer salaries in San Francisco, CA</a></span>,
#  <span class="mat">Learn more about working at <a href="/cmp/Apple" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=b1c75056addc71fd&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=c1099851e9794854');">Apple</a></span>,
#  <span class="mat">Related forums: <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a> - <a href="/forum/cmp/Apple.html">Apple</a></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Virta Health</span>\n</span>,
#  <span itemprop="name">\n    Virta Health</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span>,
#  <span itemprop="addressLocality">San Francisco, CA</span>,
#  <span class="summary" itemprop="description">\nGood understanding of statistics, clinical study <b>data</b> analysis, and clinical informatics practices including handling of Protected Health Information....</span>,
#  <span class="iaLabel"> Easily apply</span>,
#  <span class="date">1 hour ago</span>,
#  <span class="tt_set" id="tt_set_8"> - <span class="savelink2" id="savelink2_ebb9029368f01335"><a class="sl resultLink save-job-link" href="#" id="sj_ebb9029368f01335" onclick="changeJobState('ebb9029368f01335', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('ebb9029368f01335'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_ebb9029368f01335"><a class="sl resultLink save-job-link" href="#" id="sj_ebb9029368f01335" onclick="changeJobState('ebb9029368f01335', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/q-Virta-Health-l-San-Francisco,-CA-jobs.html" rel="nofollow">Virta Health jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Clinical+Informatic+Scientist&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Clinical Informatic Scientist salaries in San Francisco, CA</a></span>,
#  <span class="mat">Related forums: <a href="/forum/cmp/Virta-Health.html">Virta Health</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span>,
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Stitch-Fix" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=0aab0ad01a77733a&amp;jcid=1c70eede37c5caee')" target="_blank">\n        Stitch Fix</a></span>\n</span>,
#  <span itemprop="name">\n<a href="/cmp/Stitch-Fix" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=0aab0ad01a77733a&amp;jcid=1c70eede37c5caee')" target="_blank">\n        Stitch Fix</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 40.8px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 40.8px;"><!-- --></span>,
#  <span class="slNoUnderline">36 reviews</span>,
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span></span>,
#  <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">San Francisco, CA</span></span>,
#  <span itemprop="addressLocality">San Francisco, CA</span>,
#  <span class="summary" itemprop="description">\nHigh skill in <b>data</b> visualization (big plus). Strong skills in statistics, probability, and/or machine learning. Fluency in R, Python, or Julia....</span>,
#  <span class="iaLabel"> Easily apply</span>,
#  <span class="date">8 days ago</span>,
#  <span class="tt_set" id="tt_set_9"> - <span class="savelink2" id="savelink2_0aab0ad01a77733a"><a class="sl resultLink save-job-link" href="#" id="sj_0aab0ad01a77733a" onclick="changeJobState('0aab0ad01a77733a', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_9" onclick="toggleMoreLinks('0aab0ad01a77733a'); return false;">more...</a></span>,
#  <span class="savelink2" id="savelink2_0aab0ad01a77733a"><a class="sl resultLink save-job-link" href="#" id="sj_0aab0ad01a77733a" onclick="changeJobState('0aab0ad01a77733a', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>,
#  <span class="mat">View all <a href="/q-Stitch-Fix-l-San-Francisco,-CA-jobs.html" rel="nofollow">Stitch Fix jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span>,
#  <span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=San+Francisco%2C+CA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in San Francisco, CA</a></span>,
#  <span class="mat">Learn more about working at <a href="/cmp/Stitch-Fix" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=0aab0ad01a77733a&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=1c70eede37c5caee');">Stitch Fix</a></span>,
#  <span class="mat">Related forums: <a href="/forum/cmp/Stitch-Fix.html">Stitch Fix</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span>,
#  <span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Marin-Software" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=e5fe343626d28fe4&amp;jcid=05ffa6d1d168b61e')" target="_blank">\n        Marin Software</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span>,
#  <span class="slNoUnderline">17 reviews</span>,
#  <span class="location">San Francisco, CA 94105</span>,
#  <span class="summary">Join Marin Software as a <b>Data</b> <b>Scientist</b> to apply your real world experience of <b>data</b> analysis and machine learning techniques on vast <b>data</b> sets....</span>,
#  <span class="iaLabel"> Easily apply</span>,
#  <span class="date">30+ days ago</span>,
#  <span class="tt_set" id="tt_set_13"></span>,
#  <span class="sdn">Sponsored</span>,
#  <span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Intuit" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=a00879381d1e13cf&amp;jcid=9784ae78e9834539')" target="_blank">\n        Intuit</a></span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 52.199997px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 52.199997px;"><!-- --></span>,
#  <span class="slNoUnderline">470 reviews</span>,
#  <span class="location">Mountain View, CA 94043</span>,
#  <span class="summary">Qualifications 2-3+ years in SMB or consumer lending risk management Hands-on experience in predictive modeling methods, <b>data</b> mining/machine learning techniques...</span>,
#  <span class="date">30+ days ago</span>,
#  <span class="tt_set" id="tt_set_14"></span>,
#  <span class="sdn">Sponsored</span>,
#  <span>\nNever miss a job. Get new jobs emailed to you daily.</span>,
#  <span class="jobalerts_title" id="bjobalertlabel"><span aria-label="alert icon" class="ico" role="img"></span>Get email updates for the latest <b>data scientist jobs in San Francisco, CA</b></span>,
#  <span aria-label="alert icon" class="ico" role="img"></span>,
#  <span id="bjobalerttext"></span>,
#  <span id="bjobalertsending"></span>,
#  <span class="indeed-apply-button"><span class="indeed-apply-button-inner"><input class="indeed-apply-button-label" id="balertsubmit" type="submit" value="Activate"/></span></span>,
#  <span class="indeed-apply-button-inner"><input class="indeed-apply-button-label" id="balertsubmit" type="submit" value="Activate"/></span>,
#  <span>Also get an email with jobs recommended just for me</span>,
#  <span class="caption">\nYou can cancel email alerts at any time.</span>,
#  <span class="pn">2</span>,
#  <span class="pn">3</span>,
#  <span class="pn">4</span>,
#  <span class="pn">5</span>,
#  <span class="pn"><span class="np">Next\xa0\xbb</span></span>,
#  <span class="np">Next\xa0\xbb</span>,
#  <span class="jobalerts_title" id="tjobalertlabel"><span aria-label="alert icon" class="ico" role="img"></span>Get new jobs for this search by email</span>,
#  <span aria-label="alert icon" class="ico" role="img"></span>,
#  <span id="tjobalerttext"></span>,
#  <span id="tjobalertsending"></span>,
#  <span>Also get an email with jobs recommended just for me</span>,
#  <span class="indeed-apply-button"><span class="indeed-apply-button-inner"><input class="indeed-apply-button-label" id="talertsubmit" type="submit" value="Activate"/></span></span>,
#  <span class="indeed-apply-button-inner"><input class="indeed-apply-button-label" id="talertsubmit" type="submit" value="Activate"/></span>,
#  <span class="caption">\nYou can cancel email alerts at any time.</span>,
#  <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span></span>,
#  <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span>,
#  <span class="ico" id="univsrch-salary-icon"></span>,
#  <span class="univsrch-salary-indicator-min">$97,495</span>,
#  <span class="univsrch-salary-indicator-max">$198,631</span>,
#  <span class="univsrch-salary-indicator-bar-left"></span>,
#  <span class="univsrch-salary-indicator-bar-line"></span>,
#  <span class="univsrch-salary-indicator-bar-dot"></span>,
#  <span class="univsrch-salary-indicator-bar-right"></span>,
#  <span class="univsrch-salary-indicator-label-common">Common</span>,
#  <span>\xd7</span>,
#  <span class="logo_center_helper"></span>,
#  <span class="logo_center_helper"></span>,
#  <span class="gaj_heading">Indeed helps people get jobs:</span>]

# %%
re_tag = re.compile("summary")
span_tag = b.find('span', attrs={'class': re_tag})

# %%
span_tag.text
# Out:
# u'Requirements for all data scientists. Expert in Python and core libraries used by data scientists (Numpy, Scipy, Pandas, Scikit-learn, Matplotlib/Seaborn, etc.)...'

# %%
#### UFO ######

# SCRAPE ALL SIGHTINGS in 2016
# Plan of action
# 1. Figure out the pattern to get a certain year and month from nuforc
# 2. Scrape each sightings
# 3. Make a dataframe out of it
# 4. make a day column
# 5. graph each day in 2016 and see which day had the most! (Is it July 4th?)

# %%
##### TWITTER ######

# Create a dataframe where each row is a tweet that uses any tag (or tags) you choose!
# include a column for date, text, user handle, user name, and user image
# You can use the normal query method and not stream for this!
